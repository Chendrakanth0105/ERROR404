# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Load the dataset

# %%
import os
current_path = os.getcwd()
print("Current Path:", current_path)
# Out:
# Current Path: /Users/chendrakanth/Library/Mobile Documents/com~apple~CloudDocs/Chandu/Projects/My-Projects/Hackathon/ERROR404

# %%
stud= pd.read_csv(current_path+'/Dataset/StudentInfo.csv')

# %%
print('Total number of students:',len(stud))
# Out:
# Total number of students: 1044

# %% [markdown]
# Spliting the data to 3 datasets.

# %%
stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %%
#Dataset Columns
stud.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Dataset description
stud.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %%
# First 5 values of dataset
stud.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#Last 5 values of dataset
stud.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1039    SLA   F   19       R     GT3       T     2     3  services     other
# 1040    SLA   F   18       U     LE3       T     3     1   teacher  services
# 1041    SLA   F   18       U     GT3       T     1     1     other     other
# 1042    SLA   M   17       U     LE3       T     3     1  services  services
# 1043    SLA   M   18       R     LE3       T     3     2  services     other
#
#       ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1039  ...      5        4      2     1     2      5        4  10  11  10
# 1040  ...      4        3      4     1     1      1        4  15  15  16
# 1041  ...      1        1      1     1     1      5        6  11  12   9
# 1042  ...      2        4      5     3     4      2        6  10  10  10
# 1043  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
# To check any null values present in dataset
stud.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
# To check any null values present in dataset pictorially
sns.heatmap(stud.isnull(),cmap="rainbow",yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# ### Student's sex

# %%
# Number of female students
f_stud = len(stud[stud['sex'] == 'F'])
print('Number of female students:',f_stud)

 # Number of male students
m_stud = len(stud[stud['sex'] == 'M'])
print('Number of male students:',m_stud)
# Out:
# Number of female students: 591
# Number of male students: 453

# %%
# male & female student representaion on countplot
sns.set_style('whitegrid')
sns.countplot(x='sex',data=stud,palette='plasma')
# Out:
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/3811529051.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=stud,palette='plasma')
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### The gender distribution is pretty even.

# %% [markdown]
# ### Age of Students

# %%
# Kernel Density Estimations
b = sns.kdeplot(stud['age'])
b.axes.set_title('Ages of students')
b.set_xlabel('Age')
b.set_ylabel('Count')
plt.show()

# %%
b = sns.countplot(x='age',hue='sex', data=stud, palette='inferno')
b.axes.set_title('Number of Male & Female students in different age groups')
b.set_xlabel("Age")
b.set_ylabel("Count")
plt.show()

# %% [markdown]
# ### Students from Urban & Rural Areas

# %%
# Number of urban areas students
u_stud = len(stud[stud['address'] == 'U'])
print('Number of Urban students:',u_stud)

# Number of rural areas students
r_stud = len(stud[stud['address'] == 'R'])
print('Number of Rural students:',r_stud)
# Out:
# Number of Urban students: 759
# Number of Rural students: 285

# %%
sns.set_style('whitegrid')
# urban & rural representaion on countplot
sns.countplot(x='address',data=stud,palette='magma')
# Out:
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/1350312528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='address',data=stud,palette='magma')
# <Axes: xlabel='address', ylabel='count'>

# %% [markdown]
# ### Approximately 72.7% students come from urban region and 27.29% from rural region.

# %%
sns.countplot(x='address',hue='G3',data=stud,palette='Oranges')
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %% [markdown]
# ### EDA - Exploratory Data Analysis
# 1. Does age affect final grade?

# %%
b= sns.boxplot(x='age', y='G3',data=stud,palette='gist_heat')
b.axes.set_title('Age vs Final Grade')
# Out:
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/4011241504.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b= sns.boxplot(x='age', y='G3',data=stud,palette='gist_heat')
# Text(0.5, 1.0, 'Age vs Final Grade')

# %% [markdown]
# 1. Plotting the distribution rather than statistics would help us better understand the data.
# 2. The above plot shows that the median grades of the three age groups(15,16,17) are similar. Note the skewness of age group 19. (may be due to sample size). Age group 20 seems to score highest grades among all.

# %%
b = sns.swarmplot(x='age', y='G3',hue='sex', data=stud,palette='PiYG')
b.axes.set_title('Does age affect final grade?')
# Out:
# /Users/chendrakanth/.local/share/virtualenvs/ERROR404-TD4UYz4g/lib/python3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 55.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/chendrakanth/.local/share/virtualenvs/ERROR404-TD4UYz4g/lib/python3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 66.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/chendrakanth/.local/share/virtualenvs/ERROR404-TD4UYz4g/lib/python3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 64.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### 2. Do urban students perform better than rural students?

# %%
# Grade distribution by address
sns.kdeplot(stud.loc[stud['address'] == 'U', 'G3'], label='Urban', shade = True)
sns.kdeplot(stud.loc[stud['address'] == 'R', 'G3'], label='Rural', shade = True)
plt.title('Do urban students score higher than rural students?')
plt.xlabel('Grade');
plt.ylabel('Density')
plt.show()
# Out:
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/2204101905.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(stud.loc[stud['address'] == 'U', 'G3'], label='Urban', shade = True)
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/2204101905.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(stud.loc[stud['address'] == 'R', 'G3'], label='Rural', shade = True)

# %% [markdown]
# ### The above graph clearly shows there is not much difference between the grades based on location.

# %% [markdown]
# ### Encoding categorical variables using LabelEncoder()

# %%
stud.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
stud.iloc[:,0]=le.fit_transform(stud.iloc[:,0])
stud.iloc[:,1]=le.fit_transform(stud.iloc[:,1])
stud.iloc[:,3]=le.fit_transform(stud.iloc[:,3])
stud.iloc[:,4]=le.fit_transform(stud.iloc[:,4])
stud.iloc[:,5]=le.fit_transform(stud.iloc[:,5])
stud.iloc[:,8]=le.fit_transform(stud.iloc[:,8])
stud.iloc[:,9]=le.fit_transform(stud.iloc[:,9])
stud.iloc[:,10]=le.fit_transform(stud.iloc[:,10])
stud.iloc[:,11]=le.fit_transform(stud.iloc[:,11])
stud.iloc[:,15]=le.fit_transform(stud.iloc[:,15])
stud.iloc[:,16]=le.fit_transform(stud.iloc[:,16])
stud.iloc[:,17]=le.fit_transform(stud.iloc[:,17])
stud.iloc[:,18]=le.fit_transform(stud.iloc[:,18])
stud.iloc[:,19]=le.fit_transform(stud.iloc[:,19])
stud.iloc[:,20]=le.fit_transform(stud.iloc[:,20])
stud.iloc[:,21]=le.fit_transform(stud.iloc[:,21])
stud.iloc[:,22]=le.fit_transform(stud.iloc[:,22])

# %%
stud.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu Mjob Fjob  ... famrel  \
# 0      0   0   18       1       0       0     4     4    0    4  ...      4
# 1      0   0   17       1       0       1     1     1    0    2  ...      5
# 2      0   0   15       1       1       1     1     1    0    2  ...      4
# 3      0   0   15       1       0       1     4     2    1    3  ...      3
# 4      0   0   16       1       0       1     3     3    2    2  ...      4
#
#   freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0        3      4     1     1      3        6   5   6   6
# 1        3      3     1     1      3        4   5   5   6
# 2        3      2     2     3      3       10   7   8  10
# 3        2      2     1     1      5        2  15  14  15
# 4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
stud.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu Mjob Fjob  ...  \
# 1039      3   0   19       0       0       1     2     3    3    2  ...
# 1040      3   0   18       1       1       1     3     1    4    3  ...
# 1041      3   0   18       1       0       1     1     1    2    2  ...
# 1042      3   1   17       1       1       1     3     1    3    3  ...
# 1043      3   1   18       0       1       1     3     2    3    2  ...
#
#      famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1039      5        4      2     1     2      5        4  10  11  10
# 1040      4        3      4     1     1      1        4  15  15  16
# 1041      1        1      1     1     1      5        6  11  12   9
# 1042      2        4      5     3     4      2        6  10  10  10
# 1043      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
studG1 = stud.drop(['G2','G3'], axis = 1)
studG2 = stud.drop(['G1','G3'], axis = 1)
studG3 = stud.drop(['G1','G2'], axis = 1)

# %%
studG3.corr()
# Out:
#               school       sex       age   address   famsize   Pstatus  \
# school      1.000000 -0.065217  0.242588 -0.234020  0.043369 -0.012238
# sex        -0.065217  1.000000 -0.038832  0.011556  0.094361  0.051337
# age         0.242588 -0.038832  1.000000 -0.071257  0.013290  0.006887
# address    -0.234020  0.011556 -0.071257  1.000000  0.054484 -0.074097
# famsize     0.043369  0.094361  0.013290  0.054484  1.000000 -0.207302
# Pstatus    -0.012238  0.051337  0.006887 -0.074097 -0.207302  1.000000
# Medu       -0.179277  0.109387 -0.130196  0.179720 -0.025556 -0.077133
# Fedu       -0.161295  0.070786 -0.138521  0.124303 -0.047290 -0.049156
# Mjob       -0.121030  0.169959 -0.072088  0.148470  0.038054 -0.035206
# Fjob       -0.067660  0.083938 -0.045305 -0.002097 -0.069065  0.047796
# reason     -0.107647 -0.026595 -0.022774 -0.013449  0.012285 -0.019548
# guardian   -0.003505 -0.048676  0.275643 -0.026218 -0.000690 -0.146354
# ...

# %%
# Correlation wrt G3
studG3.corr()['G3'].sort_values()
# Out:
# failures     -0.383145
# Dalc         -0.129642
# age          -0.125282
# Walc         -0.115740
# traveltime   -0.102627
# romantic     -0.098363
# goout        -0.097877
# health       -0.080079
# schoolsup    -0.079346
# guardian     -0.077320
# freetime     -0.064890
# paid         -0.049388
# absences     -0.045671
# sex          -0.031472
# Pstatus      -0.030693
# school       -0.012249
# famsup        0.013313
# activities    0.033998
# nursery       0.039950
# Fjob          0.040541
# famrel        0.054461
# famsize       0.061209
# Mjob          0.105640
# internet      0.107064
# reason        0.108671
# address       0.117696
# Fedu          0.159796
# studytime     0.161629
# Medu          0.201472
# higher        0.236578
# G3            1.000000
# Name: G3, dtype: float64

# %%
# Find correlations with the Grade
most_correlated = studG3.corr().abs()['G3'].sort_values(ascending=False)

# Maintain the top 8 most correlation features with Grade
most_correlated = most_correlated[:11]
most_correlated
# Out:
# G3           1.000000
# failures     0.383145
# higher       0.236578
# Medu         0.201472
# studytime    0.161629
# Fedu         0.159796
# Dalc         0.129642
# age          0.125282
# address      0.117696
# Walc         0.115740
# reason       0.108671
# Name: G3, dtype: float64

# %%
studG3 = studG3.loc[:, most_correlated.index]
studG3.head()
# Out:
#    G3  failures higher  Medu  studytime  Fedu  Dalc  age address  Walc reason
# 0   6         0      1     4          2     4     1   18       1     1      0
# 1   6         0      1     1          2     1     1   17       1     1      0
# 2  10         3      1     1          2     1     2   15       1     3      2
# 3  15         0      1     4          3     2     1   15       1     1      1
# 4  10         0      1     3          2     3     1   16       1     2      1

# %% [markdown]
# ### Failure Attribute

# %%
b = sns.swarmplot(x=studG3['failures'],y=studG3['G3'],palette='autumn')
b.axes.set_title('Previous Failures vs Final Grade(G3)')
# Out:
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/3559169158.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.swarmplot(x=studG3['failures'],y=studG3['G3'],palette='autumn')
# /Users/chendrakanth/.local/share/virtualenvs/ERROR404-TD4UYz4g/lib/python3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 72.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/chendrakanth/.local/share/virtualenvs/ERROR404-TD4UYz4g/lib/python3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Previous Failures vs Final Grade(G3)')
# ...

# %% [markdown]
# ### Observation : Student with less previous failures usually score higher

# %% [markdown]
# ### Family Education Attribute ( Fedu + Medu )

# %%
fa_edu = studG3['Fedu'] + studG3['Medu']
b = sns.swarmplot(x=fa_edu,y=studG3['G3'],palette='summer')
b.axes.set_title('Family Education vs Final Grade(G3)')
# Out:
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/695313941.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.swarmplot(x=fa_edu,y=studG3['G3'],palette='summer')
# /Users/chendrakanth/.local/share/virtualenvs/ERROR404-TD4UYz4g/lib/python3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 42.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/chendrakanth/.local/share/virtualenvs/ERROR404-TD4UYz4g/lib/python3.9/site-packages/seaborn/categorical.py:3370: UserWarning: 41.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### Observation : Educated families result in higher grades

# %% [markdown]
# ### Wish to go for Higher Education Attribute

# %%
b = sns.boxplot(x=studG3['higher'],y=studG3['G3'],palette='binary')
b.axes.set_title('Higher Education vs Final Grade(G3)')
# Out:
# /var/folders/cl/h7zhc7mx0rq14df8lfmtf06m0000gn/T/ipykernel_17959/2968538845.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.boxplot(x=studG3['higher'],y=studG3['G3'],palette='binary')
# Text(0.5, 1.0, 'Higher Education vs Final Grade(G3)')

# %% [markdown]
# ### Observation : Students who wish to go for higher studies score more

# %% [markdown]
# ## Modelling

# %%
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy

# %%
# splitting the data into training and testing data (75% and 25%)
# we mention the random state to achieve the same split everytime we run the code
X = studG3.drop(['G3'], axis = 1)
y = studG3['G3']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.dummy import DummyRegressor

def regression_models_evaluation(X_train, X_test, y_train, y_test):
    # Linear Regression
    linear_reg = LinearRegression()
    linear_reg.fit(X_train, y_train)
    linear_pred = linear_reg.predict(X_test)
    linear_mse = mean_squared_error(y_test, linear_pred)
    print(f"Linear Regression MSE: {linear_mse}")

    # ElasticNet Regression
    elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
    elastic_net.fit(X_train, y_train)
    elastic_net_pred = elastic_net.predict(X_test)
    elastic_net_mse = mean_squared_error(y_test, elastic_net_pred)
    print(f"ElasticNet Regression MSE: {elastic_net_mse}")

    # Random Forest
    random_forest = RandomForestRegressor(n_estimators=100, random_state=42)
    random_forest.fit(X_train, y_train)
    rf_pred = random_forest.predict(X_test)
    rf_mse = mean_squared_error(y_test, rf_pred)
    print(f"Random Forest MSE: {rf_mse}")

    # Extra Trees
    extra_trees = ExtraTreesRegressor(n_estimators=100, random_state=42)
    extra_trees.fit(X_train, y_train)
    et_pred = extra_trees.predict(X_test)
    et_mse = mean_squared_error(y_test, et_pred)
    print(f"Extra Trees MSE: {et_mse}")

    # Support Vector Machine (SVM)
    svm_model = SVR(kernel='linear')
    svm_model.fit(X_train, y_train)
    svm_pred = svm_model.predict(X_test)
    svm_mse = mean_squared_error(y_test, svm_pred)
    print(f"SVM MSE: {svm_mse}")

    # Gradient Boosting
    gradient_boosting = GradientBoostingRegressor(n_estimators=100, random_state=42)
    gradient_boosting.fit(X_train, y_train)
    gb_pred = gradient_boosting.predict(X_test)
    gb_mse = mean_squared_error(y_test, gb_pred)
    print(f"Gradient Boosting MSE: {gb_mse}")

    # Baseline Model (Dummy Regressor)
    dummy_regressor = DummyRegressor(strategy='mean')
    dummy_regressor.fit(X_train, y_train)
    dummy_pred = dummy_regressor.predict(X_test)
    dummy_mse = mean_squared_error(y_test, dummy_pred)
    print(f"Baseline (Dummy) MSE: {dummy_mse}")

# %%
regression_models_evaluation(X_train, X_test, y_train, y_test)
# Out:
# Linear Regression MSE: 13.573158826329777
# ElasticNet Regression MSE: 13.2360255631486
# Random Forest MSE: 14.533700204511218
# Extra Trees MSE: 17.591156152618137
# SVM MSE: 13.211357517157646
# Gradient Boosting MSE: 13.91653811970359
# Baseline (Dummy) MSE: 15.204929463748329

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Fit Linear Regression model
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)

# Get feature coefficients
feature_coefficients = linear_reg.coef_

# Create a DataFrame to visualize feature coefficients
coefficients_df = pd.DataFrame({'Feature': X_train.columns, 'Coefficient': feature_coefficients})
coefficients_df = coefficients_df.sort_values(by='Coefficient', ascending=False)

# Plot feature coefficients
plt.figure(figsize=(10, 6))
plt.barh(coefficients_df['Feature'], coefficients_df['Coefficient'])
plt.xlabel('Coefficient')
plt.title('Linear Regression Feature Coefficients')
plt.show()

# %%
from sklearn.model_selection import cross_val_score

def regression_models_evaluation_with_cv(X, y):
    # Linear Regression
    linear_reg = LinearRegression()
    linear_cv_scores = -cross_val_score(linear_reg, X, y, scoring='neg_mean_squared_error', cv=5)
    print(f"Linear Regression Cross-Validation MSE Scores: {linear_cv_scores}")
    print(f"Mean CV MSE: {linear_cv_scores.mean()}")

    # ElasticNet Regression
    elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
    elastic_net_cv_scores = -cross_val_score(elastic_net, X, y, scoring='neg_mean_squared_error', cv=5)
    print(f"ElasticNet Regression Cross-Validation MSE Scores: {elastic_net_cv_scores}")
    print(f"Mean CV MSE: {elastic_net_cv_scores.mean()}")

    # Random Forest
    random_forest = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_cv_scores = -cross_val_score(random_forest, X, y, scoring='neg_mean_squared_error', cv=5)
    print(f"Random Forest Cross-Validation MSE Scores: {rf_cv_scores}")
    print(f"Mean CV MSE: {rf_cv_scores.mean()}")

    # Extra Trees
    extra_trees = ExtraTreesRegressor(n_estimators=100, random_state=42)
    et_cv_scores = -cross_val_score(extra_trees, X, y, scoring='neg_mean_squared_error', cv=5)
    print(f"Extra Trees Cross-Validation MSE Scores: {et_cv_scores}")
    print(f"Mean CV MSE: {et_cv_scores.mean()}")

    # Support Vector Machine (SVM)
    svm_model = SVR(kernel='linear')
    svm_cv_scores = -cross_val_score(svm_model, X, y, scoring='neg_mean_squared_error', cv=5)
    print(f"SVM Cross-Validation MSE Scores: {svm_cv_scores}")
    print(f"Mean CV MSE: {svm_cv_scores.mean()}")

    # Gradient Boosting
    gradient_boosting = GradientBoostingRegressor(n_estimators=100, random_state=42)
    gb_cv_scores = -cross_val_score(gradient_boosting, X, y, scoring='neg_mean_squared_error', cv=5)
    print(f"Gradient Boosting Cross-Validation MSE Scores: {gb_cv_scores}")
    print(f"Mean CV MSE: {gb_cv_scores.mean()}")

    # Baseline Model (Dummy Regressor)
    dummy_regressor = DummyRegressor(strategy='mean')
    dummy_cv_scores = -cross_val_score(dummy_regressor, X, y, scoring='neg_mean_squared_error', cv=5)
    print(f"Baseline (Dummy) Cross-Validation MSE Scores: {dummy_cv_scores}")
    print(f"Mean CV MSE: {dummy_cv_scores.mean()}")

# %%
regression_models_evaluation_with_cv(X, y)
# Out:
# Linear Regression Cross-Validation MSE Scores: [17.84990493 20.44472438  5.42931731  9.98317899 12.2270083 ]
# Mean CV MSE: 13.186826782498704
# ElasticNet Regression Cross-Validation MSE Scores: [18.13787801 19.71912542  5.3138431  10.50900868 12.36045942]
# Mean CV MSE: 13.208062923938382
# Random Forest Cross-Validation MSE Scores: [15.63842052 20.42573665  6.57262096 13.34966835 12.52746811]
# Mean CV MSE: 13.702782919063782
# Extra Trees Cross-Validation MSE Scores: [15.78406243 22.4942452  10.5379355  18.28130307 13.7251793 ]
# Mean CV MSE: 16.164545100449843
# SVM Cross-Validation MSE Scores: [18.64312419 20.89331496  5.12533505  8.88524293 12.01957939]
# Mean CV MSE: 13.113319302672107
# Gradient Boosting Cross-Validation MSE Scores: [17.91847201 20.03129952  4.76645548 10.6720511  12.74638584]
# Mean CV MSE: 13.22693279009683
# Baseline (Dummy) Cross-Validation MSE Scores: [21.7990084  20.84534168  6.86085458 12.13200443 15.57271248]
# Mean CV MSE: 15.441984314685204
